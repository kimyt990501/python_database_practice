# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
url = 'http://www.statiz.co.kr/stat.php?opt=0&sopt=0&re=0&ys=2022&ye=2022&se=0&te=&tm=&ty=0&qu=auto&po=0&as=&ae=&hi=&un=&pl=&da=1&o1=WAR_ALL_ADJ&o2=TPA&de=1&lr=0&tr=&cv=&ml=1&sn=30&si=&cn='

response = requests.get(url)

html = response.text
soup = BeautifulSoup(html, 'html.parser')

# %%
temp = soup.find_all("table")[0]

# %%
# 빈 데이터 프레임 만들어두기
df = pd.DataFrame(index = range(30), columns = ["순위", "선수명", "팀명", "WAR", "경기", "타석", "타수", "득점", "안타", "2루타", "3루타", "홈런", "루타", "타점", 
                                                 "도루", "도루실패", "볼넷", "사구", "고의사구", "삼진", "병살타", "희생타", "희생플라이", "타율", "출루율", "장타율", "OPS", "wOBA", "wRC+", "WAR2", "WPA"])
data_2022 = df

# %%
# 중간에 추가 돼있는 칼럼을 제외하고 불러오기
l = 0
temp2 = temp.find_all("tr")[2]
for j in range(2,36):
    temp2 = temp.find_all("tr")[j]
    if len(temp2.find_all("td")) == 31:
        for i in range(31):
            temp3 = temp2.find_all("td")[i]
            data_2022.iloc[l,i] = temp3.get_text()
        l += 1
data_2022
# Out:
#     순위    선수명     팀명     WAR     경기     타석     타수     득점     안타   2루타  ...  \
# 0    1    이정후  22키CF   9.23    142    627    553     85    193    36   ...
# 1    2    피렐라  22삼LF   7.40    141    630    561    102    192    33   ...
# 2    3    나성범  22KRF   6.50    144    649    563     92    180    39   ...
# 3    4    오지환  22LSS   5.77    142    569    494     75    133    16   ...
# 4    5     최정  22S3B   5.15    121    505    414     80    110    21   ...
# 5    6    터크먼  22한CF   4.98    144    648    575     88    166    37   ...
# 6    7  소크라테스  22KCF   4.97    127    554    514     83    160    29   ...
# 7    8    김현수  22LLF   4.88    141    604    524     78    150    25   ...
# 8    9    김혜성  22키2B   4.80    129    566    516     81    164    18   ...
# 9   10    최지훈  22SCF   4.78    144    640    570     93    173    32   ...
# 10  11    양의지   22NC   4.61    130    510    427     61    121    24   ...
# ...

# %%
data_2022.to_csv('C:\\Users\\user\\Desktop\\resources\\baseball_player\\kbo_hitter_data_2022.csv', index=None, encoding='euc-kr')

# %%
data = pd.read_csv("C:\\Users\\user\\Desktop\\resources\\baseball_player\\kbo_hitter_data_2022.csv", encoding='euc-kr')
data
# Out:
#     순위    선수명     팀명   WAR   경기   타석   타수   득점   안타  2루타  ...  희생타  희생플라이  \
# 0    1    이정후  22키CF  9.23  142  627  553   85  193   36  ...    0      3
# 1    2    피렐라  22삼LF  7.40  141  630  561  102  192   33  ...    0      2
# 2    3    나성범  22KRF  6.50  144  649  563   92  180   39  ...    0      5
# 3    4    오지환  22LSS  5.77  142  569  494   75  133   16  ...    3      3
# 4    5     최정  22S3B  5.15  121  505  414   80  110   21  ...    0      6
# 5    6    터크먼  22한CF  4.98  144  648  575   88  166   37  ...    0      2
# 6    7  소크라테스  22KCF  4.97  127  554  514   83  160   29  ...    0      4
# 7    8    김현수  22LLF  4.88  141  604  524   78  150   25  ...    0      3
# 8    9    김혜성  22키2B  4.80  129  566  516   81  164   18  ...    0      3
# 9   10    최지훈  22SCF  4.78  144  640  570   93  173   32  ...   12      4
# 10  11    양의지   22NC  4.61  130  510  427   61  121   24  ...    0     10
# 11  12    박건우  22NCF  4.47  111  463  408   52  137   18  ...    0      3
# ...
